# %% [markdown]
# **set up environment:**

# %%
# !pip install transformers seqeval[gpu]
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer, BertConfig, BertForTokenClassification
from torch import cuda
device = 'cuda' if cuda.is_available() else 'cpu'
import json
import os
from seqeval.metrics import classification_report
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Collecting seqeval[gpu]
#   Downloading seqeval-1.2.2.tar.gz (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 699.2 kB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.10/dist-packages (from seqeval[gpu]) (1.2.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval[gpu]) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval[gpu]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.21.3->seqeval[gpu]) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Building wheels for collected packages: seqeval
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.2-py3-none-any.whl size=16162 sha256=4cff9de0c38dda9cc3b4fa5380af1852b5e5093856129ba9e6b69421ea80e45d
#   Stored in directory: /root/.cache/pip/wheels/1a/67/4a/ad4082dd7dfc30f2abfe4d80a2ed5926a506eb8a972b4767fa
# Successfully built seqeval
# Installing collected packages: seqeval
# Successfully installed seqeval-1.2.2

# %%
from pathlib import Path

dir_path = 'datas'
distant_label_dir_path = 'distant-labeled-datas'

def get_data(data_path):
  sentences = []
  labels = []
  for dir in Path(data_path).glob('*'):
    for filename in Path(dir).glob('**/*.json'):
        path = filename
        if os.path.isfile(path):
          f = open(path)
          print(path, f)
          file_data = json.load(f)
          for item in file_data:
            sentences.append(item['words'])
            labels.append(item['labels'])
  return (sentences, labels)

is_distant_label = True
sentences, labels = get_data(dir_path)
data = pd.DataFrame({'sentence': sentences, 'word_labels': labels})

if is_distant_label:
  d_sentences, d_labels = get_data(distant_label_dir_path)
  d_data = pd.DataFrame({'sentence': d_sentences, 'word_labels': d_labels})
  print(d_data)

print(data)
# Out:
# datas/final_slides_json_manual/CS-1541 Lecture Notes/CS1541_Lecture1.1_Introduction.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-1541 Lecture Notes/CS1541_Lecture1.1_Introduction.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0449 Lecture Slides/01_CS449_Introduction.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0449 Lecture Slides/01_CS449_Introduction.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0449 Lecture Slides/02_CS449_Data-Representation.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0449 Lecture Slides/02_CS449_Data-Representation.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-1567 Lecture Notes/09_10_blobs_detections_handout.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-1567 Lecture Notes/09_10_blobs_detections_handout.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-1567 Lecture Notes/07_kobuki_node_handout.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-1567 Lecture Notes/07_kobuki_node_handout.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-1567 Lecture Notes/15_launch_file_handout.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-1567 Lecture Notes/15_launch_file_handout.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-1567 Lecture Notes/02_introduction_ros_handout.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-1567 Lecture Notes/02_introduction_ros_handout.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-1567 Lecture Notes/14_pid_control_handout.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-1567 Lecture Notes/14_pid_control_handout.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-1567 Lecture Notes/05_joy_node_handout.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-1567 Lecture Notes/05_joy_node_handout.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-1567 Lecture Notes/03_publisher_subscriber_handout.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-1567 Lecture Notes/03_publisher_subscriber_handout.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec12.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec12.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec18.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec18.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec15.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec15.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec01.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec01.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec16.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec16.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec05.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec05.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec09.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec09.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec07.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec07.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec19.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec19.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec14.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec14.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec03.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec03.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec22.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec22.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec21.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec21.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec23.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec23.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec20.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec20.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec11.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec11.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec08.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec08.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec02.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec02.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec06.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec06.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec04.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec04.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec13.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec13.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec10.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec10.json' mode='r' encoding='UTF-8'>
# datas/final_slides_json_manual/CS-0441 Lecture Slides/lec17.json <_io.TextIOWrapper name='datas/final_slides_json_manual/CS-0441 Lecture Slides/lec17.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.6_SIMD_And_GPUs.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.6_SIMD_And_GPUs.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.5_Multi_Processors.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.5_Multi_Processors.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture1.3_Technology_Constraints.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture1.3_Technology_Constraints.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.2_Cache_Design.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.2_Cache_Design.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.4_Virtual_Memory.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.4_Virtual_Memory.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.6_Superscalar_Processors.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.6_Superscalar_Processors.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.4_Branch_Prediction.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.4_Branch_Prediction.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.3_Optimizing_Pipeline_Hazards.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.3_Optimizing_Pipeline_Hazards.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.5_VLIW_Processors.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.5_VLIW_Processors.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.1_Memory_Hierarchy.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.1_Memory_Hierarchy.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.3_Cache_Design2.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.3_Cache_Design2.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.1_Processor_Review.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.1_Processor_Review.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture1.2_Technology_Advances.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture1.2_Technology_Advances.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.2_Processor_Pipelining.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.2_Processor_Pipelining.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/07_cs1622-parsing-part4.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/07_cs1622-parsing-part4.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/01 - Intro and Rust.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/01 - Intro and Rust.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/06_cs1622-parsing-part3.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/06_cs1622-parsing-part3.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/05_cs1622-parsing-part2.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/05_cs1622-parsing-part2.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/06 - Bottom-up Parsing.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/06 - Bottom-up Parsing.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/17 - Local Optimization.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/17 - Local Optimization.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/02 - Rust, Strings, and Text.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/02 - Rust, Strings, and Text.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/19 - Liveness and Register Allocation.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/19 - Liveness and Register Allocation.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/10 - Advanced Typing.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/10 - Advanced Typing.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/11 - Backend and Runtime.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/11 - Backend and Runtime.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/09 - Typing.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/09 - Typing.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/05 - Top-down Parsing.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/05 - Top-down Parsing.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/07 - Semantic Analysis.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/07 - Semantic Analysis.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/18 - Global Optimization.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/18 - Global Optimization.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/13 - ABI and Codegen.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/13 - ABI and Codegen.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/08_cs1622-parsing-part5.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/08_cs1622-parsing-part5.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/16 - Control Flow Graphs and IR.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/16 - Control Flow Graphs and IR.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/03 - Lexing and Grammars.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/03 - Lexing and Grammars.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/14 - More Codegen and Arrays.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/14 - More Codegen and Arrays.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/15 - Structs and Classes, OOP.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/15 - Structs and Classes, OOP.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/08 - Scoping and Naming.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/08 - Scoping and Naming.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/04_cs1622-parsing-part1.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/04_cs1622-parsing-part1.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/12 - Dynamic Memory Management.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/12 - Dynamic Memory Management.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/04 - CFGs and ASTs.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/04 - CFGs and ASTs.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/03_CS449_Data-Representation-II.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/03_CS449_Data-Representation-II.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/16-netprog.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/16-netprog.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/17_CS449_Files-and-Directories.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/17_CS449_Files-and-Directories.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/14_CS449_The-Memory-Hierarchy.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/14_CS449_The-Memory-Hierarchy.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/10_CS449_How-Programs-Are-Made.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/10_CS449_How-Programs-Are-Made.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/04_CS449_Introduction-to-C.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/04_CS449_Introduction-to-C.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/13_CS449_Virtual-Memory.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/13_CS449_Virtual-Memory.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/08_CS449_Investigating-the-Code.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/08_CS449_Investigating-the-Code.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/07_CS449_Introduction-to-x86.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/07_CS449_Introduction-to-x86.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/06_CS449_Memory-Management.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/06_CS449_Memory-Management.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/11_CS449_How-Programs-Are-Managed.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/11_CS449_How-Programs-Are-Managed.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/15_CS449_Threads-and-Synchronization.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/15_CS449_Threads-and-Synchronization.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/05_CS449_Introduction-to-Memory.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/05_CS449_Introduction-to-Memory.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/12_CS449_How-Programs-Reproduce.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/12_CS449_How-Programs-Reproduce.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/09_CS449_buffer-overflow.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/09_CS449_buffer-overflow.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/final-review.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/final-review.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/midterm-review.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/midterm-review.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture5-Sherif’s MacBook Pro.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture5-Sherif’s MacBook Pro.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture21.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture21.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture12.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture12.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture16.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture16.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture5.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture5.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture19.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture19.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture6.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture6.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture10.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture10.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture27.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture27.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture26.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture26.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture4.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture4.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture24.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture24.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture15.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture15.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture22.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture22.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture0.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture0.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture7.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture7.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture25.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture25.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture17.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture17.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture11.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture11.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture2.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture2.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture3.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture3.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture13.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture13.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture8.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture8.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture23.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture23.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture9.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture9.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture14.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture14.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture20.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture20.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture1.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture1.json' mode='r' encoding='UTF-8'>
# distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture18.json <_io.TextIOWrapper name='distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture18.json' mode='r' encoding='UTF-8'>
#                                                sentence  \
# 0              [SIMD, and, GPUs, CS, 1541, Wonsun, Ahn]
# 1                              [SIMD, Architectures, 2]
# 2     [ISA, not, optimized, for, data, parallel, wor...
# 3     [MIPS, code, for, 𝒚, 𝒊, =, 𝒂, ∗, 𝒙, 𝒊, +, 𝒚, 𝒊...
# 4     [SIMD, (, Single, Instruction, Multiple, Data,...
# ...                                                 ...
# 2663  [Project, 3, :, OPT, Simulation, CS, 1550, –, ...
# 2664  [OPT, Implementation, Example, CS, 1550, –, Op...
# 2665  [Project, 3, :, LRU, and, miscellaneous, hints...
# 2666  [Project, 3, :, Writeup, hints, CS, 1550, –, O...
# 2667  [Problem, of, the, Day, •, How, to, keep, trac...
#
#                                             word_labels
# 0                                 [B, O, O, O, O, O, O]
# 1                                             [B, O, O]
# 2     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3     [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 4     [B, O, O, O, O, O, O, O, B, O, O, O, O, O, O, ...
# ...                                                 ...
# 2663         [O, O, O, O, O, O, O, O, B, I, O, O, O, O]
# 2664               [O, O, O, O, O, O, B, I, O, O, O, O]
# 2665   [O, O, O, O, O, O, O, O, O, O, B, I, O, O, O, O]
# 2666         [O, O, O, O, O, O, O, O, B, I, O, O, O, O]
# 2667  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
#
# [2668 rows x 2 columns]
#                                               sentence  \
# 0    [CS, 1541, Introduction, Instructor, Introduct...
# 1    [Instructor, Introduction, My, Technical, Back...
# 2    [My, World, View, ◼, Everything, is, connected...
# 3    [Collaboration, is, Replacing, Competition, ◼,...
# 4    [Supporting, Collaborative, Learning, ◼, I, do...
# ..                                                 ...
# 821  [This, has, been, easy, so, far, ,, right, ?, ...
# 822  [Sports, !, During, a, month, with, 30, days, ...
# 823  [Number, theory, Show, that, among, any, n+1, ...
# 824  [In-class, exercises, Problem, 4, :, Top, Hat,...
# 825  [Final, Thoughts, n, The, inclusion/exclusion,...
#
#                                            word_labels
# 0    [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 1    [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 2    [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 3    [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 4    [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# ..                                                 ...
# 821  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 822  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 823  [B, I, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 824  [O, O, O, O, O, O, O, O, O, O, O, O, O, O, O, ...
# 825  [O, O, O, O, B, I, O, O, O, O, O, O, O, O, O, ...
#
# [826 rows x 2 columns]

# %%
# !unzip final_slides_json_manual.zip -d datas
# !unzip final_slides_json_distant.zip -d distant-labeled-datas
# Out:
# Archive:  final_slides_json_manual.zip
#    creating: datas/final_slides_json_manual/
#    creating: datas/final_slides_json_manual/CS-0441 Lecture Slides/
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec01.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec02.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec03.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec04.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec05.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec06.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec07.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec08.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec09.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec10.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec11.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec12.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec13.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec14.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec15.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec16.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec17.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec18.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec19.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec20.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec21.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec22.json
#   inflating: datas/final_slides_json_manual/CS-0441 Lecture Slides/lec23.json
#    creating: datas/final_slides_json_manual/CS-0449 Lecture Slides/
#   inflating: datas/final_slides_json_manual/CS-0449 Lecture Slides/01_CS449_Introduction.json
#   inflating: datas/final_slides_json_manual/CS-0449 Lecture Slides/02_CS449_Data-Representation.json
#    creating: datas/final_slides_json_manual/CS-1541 Lecture Notes/
#   inflating: datas/final_slides_json_manual/CS-1541 Lecture Notes/CS1541_Lecture1.1_Introduction.json
#    creating: datas/final_slides_json_manual/CS-1550 Lecture Slides/
#    creating: datas/final_slides_json_manual/CS-1567 Lecture Notes/
#   inflating: datas/final_slides_json_manual/CS-1567 Lecture Notes/02_introduction_ros_handout.json
#   inflating: datas/final_slides_json_manual/CS-1567 Lecture Notes/03_publisher_subscriber_handout.json
#   inflating: datas/final_slides_json_manual/CS-1567 Lecture Notes/05_joy_node_handout.json
#   inflating: datas/final_slides_json_manual/CS-1567 Lecture Notes/07_kobuki_node_handout.json
#   inflating: datas/final_slides_json_manual/CS-1567 Lecture Notes/09_10_blobs_detections_handout.json
#   inflating: datas/final_slides_json_manual/CS-1567 Lecture Notes/14_pid_control_handout.json
#   inflating: datas/final_slides_json_manual/CS-1567 Lecture Notes/15_launch_file_handout.json
#    creating: datas/final_slides_json_manual/CS-1622 Lecture Slides/
# Archive:  final_slides_json_distant.zip
#    creating: distant-labeled-datas/final_slides_json_distant/
#    creating: distant-labeled-datas/final_slides_json_distant/CS-0441 Lecture Slides/
#    creating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/03_CS449_Data-Representation-II.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/04_CS449_Introduction-to-C.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/05_CS449_Introduction-to-Memory.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/06_CS449_Memory-Management.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/07_CS449_Introduction-to-x86.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/08_CS449_Investigating-the-Code.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/09_CS449_buffer-overflow.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/10_CS449_How-Programs-Are-Made.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/11_CS449_How-Programs-Are-Managed.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/12_CS449_How-Programs-Reproduce.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/13_CS449_Virtual-Memory.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/14_CS449_The-Memory-Hierarchy.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/15_CS449_Threads-and-Synchronization.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/16-netprog.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/17_CS449_Files-and-Directories.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/final-review.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-0449 Lecture Slides/midterm-review.json
#    creating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture1.2_Technology_Advances.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture1.3_Technology_Constraints.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.1_Processor_Review.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.2_Processor_Pipelining.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.3_Optimizing_Pipeline_Hazards.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.4_Branch_Prediction.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.5_VLIW_Processors.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture2.6_Superscalar_Processors.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.1_Memory_Hierarchy.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.2_Cache_Design.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.3_Cache_Design2.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.4_Virtual_Memory.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.5_Multi_Processors.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1541 Lecture Notes/CS1541_Lecture3.6_SIMD_And_GPUs.json
#    creating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture0.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture1.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture10.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture11.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture12.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture13.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture14.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture15.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture16.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture17.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture18.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture19.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture2.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture20.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture21.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture22.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture23.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture24.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture25.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture26.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture27.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture3.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture4.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture5-Sherif’s MacBook Pro.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture5.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture6.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture7.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture8.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1550 Lecture Slides/Lecture9.json
#    creating: distant-labeled-datas/final_slides_json_distant/CS-1567 Lecture Notes/
#    creating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/01 - Intro and Rust.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/02 - Rust, Strings, and Text.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/03 - Lexing and Grammars.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/04 - CFGs and ASTs.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/04_cs1622-parsing-part1.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/05 - Top-down Parsing.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/05_cs1622-parsing-part2.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/06 - Bottom-up Parsing.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/06_cs1622-parsing-part3.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/07 - Semantic Analysis.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/07_cs1622-parsing-part4.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/08 - Scoping and Naming.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/08_cs1622-parsing-part5.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/09 - Typing.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/10 - Advanced Typing.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/11 - Backend and Runtime.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/12 - Dynamic Memory Management.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/13 - ABI and Codegen.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/14 - More Codegen and Arrays.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/15 - Structs and Classes, OOP.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/16 - Control Flow Graphs and IR.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/17 - Local Optimization.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/18 - Global Optimization.json
#   inflating: distant-labeled-datas/final_slides_json_distant/CS-1622 Lecture Slides/19 - Liveness and Register Allocation.json

# %% [markdown]
# **preparing dataset and dataloader:**

# %%
MAX_LEN = 128
TRAIN_BATCH_SIZE = 4
VALID_BATCH_SIZE = 2
EPOCHS = 1
LEARNING_RATE = 1e-05
MAX_GRAD_NORM = 10
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

label2id = {
    'B': 0,
    'I': 1,
    'O': 2
 }
id2label = {
    0: 'B',
    1: 'I',
    2: 'O'
}

def tokenize_and_preserve_labels(sentence, text_labels, tokenizer):
    """
    Word piece tokenization makes it difficult to match word labels
    back up with individual word pieces. This function tokenizes each
    word one at a time so that it is easier to preserve the correct
    label for each subword. It is, of course, a bit slower in processing
    time, but it will help our model achieve higher accuracy.
    """

    tokenized_sentence = []
    labels = []

    for word, label in zip(sentence, text_labels):

        # Tokenize the word and count # of subwords the word is broken into
        tokenized_word = tokenizer.tokenize(word)
        n_subwords = len(tokenized_word)

        # Add the tokenized word to the final tokenized word list
        tokenized_sentence.extend(tokenized_word)

        # Add the same label to the new list of labels `n_subwords` times
        labels.extend([label] * n_subwords)

    return tokenized_sentence, labels

class dataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_len):
        self.len = len(dataframe)
        self.data = dataframe
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __getitem__(self, index):
        # step 1: tokenize (and adapt corresponding labels)
        sentence = self.data.sentence[index]
        word_labels = self.data.word_labels[index]
        tokenized_sentence, labels = tokenize_and_preserve_labels(sentence, word_labels, self.tokenizer)

        # step 2: add special tokens (and corresponding labels)
        tokenized_sentence = ["[CLS]"] + tokenized_sentence + ["[SEP]"] # add special tokens
        labels.insert(0, "O") # add outside label for [CLS] token
        labels.insert(-1, "O") # add outside label for [SEP] token

        # step 3: truncating/padding
        maxlen = self.max_len

        if (len(tokenized_sentence) > maxlen):
          # truncate
          tokenized_sentence = tokenized_sentence[:maxlen]
          labels = labels[:maxlen]
        else:
          # pad
          tokenized_sentence = tokenized_sentence + ['[PAD]'for _ in range(maxlen - len(tokenized_sentence))]
          labels = labels + ["O" for _ in range(maxlen - len(labels))]

        # step 4: obtain the attention mask
        attn_mask = [1 if tok != '[PAD]' else 0 for tok in tokenized_sentence]

        # step 5: convert tokens to input ids
        ids = self.tokenizer.convert_tokens_to_ids(tokenized_sentence)

        label_ids = [label2id[label] for label in labels]
        # the following line is deprecated
        #label_ids = [label if label != 0 else -100 for label in label_ids]

        return {
              'ids': torch.tensor(ids, dtype=torch.long),
              'mask': torch.tensor(attn_mask, dtype=torch.long),
              #'token_type_ids': torch.tensor(token_ids, dtype=torch.long),
              'targets': torch.tensor(label_ids, dtype=torch.long)
        }

    def __len__(self):
        return self.len

train_size = 0.8
train_dataset = data.sample(frac=train_size,random_state=200)
test_dataset = data.drop(train_dataset.index).reset_index(drop=True)
if is_distant_label:
  train_dataset = pd.concat([train_dataset, d_data])
  pass
train_dataset = train_dataset.reset_index(drop=True)

print("FULL Dataset: {}".format(data.shape))
print("TRAIN Dataset: {}".format(train_dataset.shape))
print("TEST Dataset: {}".format(test_dataset.shape))

training_set = dataset(train_dataset, tokenizer, MAX_LEN)
testing_set = dataset(test_dataset, tokenizer, MAX_LEN)

# print the first 30 tokens and corresponding labels
for token, label in zip(tokenizer.convert_ids_to_tokens(training_set[0]["ids"][:30]), training_set[0]["targets"][:30]):
  print('{0:10}  {1}'.format(token, id2label[label.item()]))


train_params = {'batch_size': TRAIN_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

test_params = {'batch_size': VALID_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

training_loader = DataLoader(training_set, **train_params)
testing_loader = DataLoader(testing_set, **test_params)
# Out:
# FULL Dataset: (826, 2)
# TRAIN Dataset: (3329, 2)
# TEST Dataset: (165, 2)
# [CLS]       O
# buying      O
# cookies     O
# !           O
# example     O
# :           O
# how         O
# many        O
# ways        O
# can         O
# we          O
# choose      O
# six         O
# cookies     O
# at          O
# a           O
# cookie      O
# shop        O
# that        O
# makes       O
# 4           O
# types       O
# of          O
# cookie      O
# ?           O
# assume      O
# that        O
# only        O
# the         O
# type        O

# %% [markdown]
# **defining the model:**

# %%
model = BertForTokenClassification.from_pretrained('bert-base-uncased',
                                                   num_labels=len(id2label),
                                                   id2label=id2label,
                                                   label2id=label2id)
model.to(device)
# Out:
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForTokenClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=3, bias=True)
# )

# %% [markdown]
# **training the model:**

# %%
ids = training_set[0]["ids"].unsqueeze(0)
mask = training_set[0]["mask"].unsqueeze(0)
targets = training_set[0]["targets"].unsqueeze(0)
ids = ids.to(device)
mask = mask.to(device)
targets = targets.to(device)
outputs = model(input_ids=ids, attention_mask=mask, labels=targets)
initial_loss = outputs[0]
initial_loss
tr_logits = outputs[1]
optimizer = torch.optim.Adam(params=model.parameters(), lr=LEARNING_RATE)

# Defining the training function on the 80% of the dataset for tuning the bert model
def train(epoch):
    tr_loss, tr_accuracy = 0, 0
    nb_tr_examples, nb_tr_steps = 0, 0
    tr_preds, tr_labels = [], []
    # put model in training mode
    model.train()

    for idx, batch in enumerate(training_loader):

        ids = batch['ids'].to(device, dtype = torch.long)
        mask = batch['mask'].to(device, dtype = torch.long)
        targets = batch['targets'].to(device, dtype = torch.long)

        outputs = model(input_ids=ids, attention_mask=mask, labels=targets)
        loss, tr_logits = outputs.loss, outputs.logits
        tr_loss += loss.item()

        nb_tr_steps += 1
        nb_tr_examples += targets.size(0)

        if idx % 100==0:
            loss_step = tr_loss/nb_tr_steps
            print(f"Training loss per 100 training steps: {loss_step}")

        # compute training accuracy
        flattened_targets = targets.view(-1) # shape (batch_size * seq_len,)
        active_logits = tr_logits.view(-1, model.num_labels) # shape (batch_size * seq_len, num_labels)
        flattened_predictions = torch.argmax(active_logits, axis=1) # shape (batch_size * seq_len,)
        # now, use mask to determine where we should compare predictions with targets (includes [CLS] and [SEP] token predictions)
        active_accuracy = mask.view(-1) == 1 # active accuracy is also of shape (batch_size * seq_len,)
        targets = torch.masked_select(flattened_targets, active_accuracy)
        predictions = torch.masked_select(flattened_predictions, active_accuracy)

        tr_preds.extend(predictions)
        tr_labels.extend(targets)

        tmp_tr_accuracy = accuracy_score(targets.cpu().numpy(), predictions.cpu().numpy())
        tr_accuracy += tmp_tr_accuracy

        # gradient clipping
        torch.nn.utils.clip_grad_norm_(
            parameters=model.parameters(), max_norm=MAX_GRAD_NORM
        )

        # backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

    epoch_loss = tr_loss / nb_tr_steps
    tr_accuracy = tr_accuracy / nb_tr_steps
    print(f"Training loss epoch: {epoch_loss}")
    print(f"Training accuracy epoch: {tr_accuracy}")

for epoch in range(EPOCHS):
  print(f"Training epoch: {epoch + 1}")
  train(epoch)
# Out:
# Training epoch: 1
# Training loss per 100 training steps: 1.013066291809082
# Training loss per 100 training steps: 0.2004959898641204
# Training loss per 100 training steps: 0.15314053985016857
# Training loss per 100 training steps: 0.13102761869538465
# Training loss per 100 training steps: 0.11609300310047636
# Training loss per 100 training steps: 0.10617885272392256
# Training loss per 100 training steps: 0.09829463621217156
# Training loss per 100 training steps: 0.09220011582659204
# Training loss per 100 training steps: 0.08778968740187204
# Training loss epoch: 0.08616033659203678
# Training accuracy epoch: 0.9616729423905286

# %% [markdown]
# **evaluating the model:**

# %%
def valid(model, testing_loader):
    # put model in evaluation mode
    model.eval()

    eval_loss, eval_accuracy = 0, 0
    nb_eval_examples, nb_eval_steps = 0, 0
    eval_preds, eval_labels = [], []

    with torch.no_grad():
        for idx, batch in enumerate(testing_loader):

            ids = batch['ids'].to(device, dtype = torch.long)
            mask = batch['mask'].to(device, dtype = torch.long)
            targets = batch['targets'].to(device, dtype = torch.long)

            outputs = model(input_ids=ids, attention_mask=mask, labels=targets)
            loss, eval_logits = outputs.loss, outputs.logits

            eval_loss += loss.item()

            nb_eval_steps += 1
            nb_eval_examples += targets.size(0)

            if idx % 100==0:
                loss_step = eval_loss/nb_eval_steps
                print(f"Validation loss per 100 evaluation steps: {loss_step}")

            # compute evaluation accuracy
            flattened_targets = targets.view(-1) # shape (batch_size * seq_len,)
            active_logits = eval_logits.view(-1, model.num_labels) # shape (batch_size * seq_len, num_labels)
            flattened_predictions = torch.argmax(active_logits, axis=1) # shape (batch_size * seq_len,)
            # now, use mask to determine where we should compare predictions with targets (includes [CLS] and [SEP] token predictions)
            active_accuracy = mask.view(-1) == 1 # active accuracy is also of shape (batch_size * seq_len,)
            targets = torch.masked_select(flattened_targets, active_accuracy)
            predictions = torch.masked_select(flattened_predictions, active_accuracy)

            eval_labels.extend(targets)
            eval_preds.extend(predictions)

            tmp_eval_accuracy = accuracy_score(targets.cpu().numpy(), predictions.cpu().numpy())
            eval_accuracy += tmp_eval_accuracy

    #print(eval_labels)
    #print(eval_preds)

    labels = [id2label[id.item()] for id in eval_labels]
    predictions = [id2label[id.item()] for id in eval_preds]

    #print(labels)
    #print(predictions)

    eval_loss = eval_loss / nb_eval_steps
    eval_accuracy = eval_accuracy / nb_eval_steps
    print(f"Validation Loss: {eval_loss}")
    print(f"Validation Accuracy: {eval_accuracy}")

    return labels, predictions

labels, predictions = valid(model, testing_loader)
print(labels, predictions)
print(classification_report([labels], [predictions]))
# Out:
# Validation loss per 100 evaluation steps: 0.10813938826322556
# Validation Loss: 0.12921170173886132
# Validation Accuracy: 0.9310568933931572
# ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'B', 'O', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'B', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'B', 'I', 'O', 'O', 'O', 'B', 'B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'B', 'O', 'O', 'O', 'B', 'B', 'B', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'B', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'B', 'I', 'I', 'I', 'I', 'O', 'O', 'O', 'O', 'B', 'I', 'I', 'I', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'B', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'B', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'B', 'B', 'I', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'B', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'B', 'B', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'B', 'O', 'B', 'B', 'B', 'B', 'I', 'O', 'B', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'B', 'O', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'I', 'I', 'O', 'B', 'I', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'I', ...
#               precision    recall  f1-score   support
#
#            _       0.50      0.62      0.55      1162
#
#    micro avg       0.50      0.62      0.55      1162
#    macro avg       0.50      0.62      0.55      1162
# weighted avg       0.50      0.62      0.55      1162

# %% [markdown]
# **inference:**

# %%
sentence = "The client node in a wide area network, which connects to a router node."

inputs = tokenizer(sentence, padding='max_length', truncation=True, max_length=MAX_LEN, return_tensors="pt")

# move to gpu
ids = inputs["input_ids"].to(device)
mask = inputs["attention_mask"].to(device)
# forward pass
outputs = model(ids, mask)
logits = outputs[0]

active_logits = logits.view(-1, model.num_labels) # shape (batch_size * seq_len, num_labels)
flattened_predictions = torch.argmax(active_logits, axis=1) # shape (batch_size*seq_len,) - predictions at the token level

tokens = tokenizer.convert_ids_to_tokens(ids.squeeze().tolist())
token_predictions = [id2label[i] for i in flattened_predictions.cpu().numpy()]
wp_preds = list(zip(tokens, token_predictions)) # list of tuples. Each tuple = (wordpiece, prediction)

word_level_predictions = []
for pair in wp_preds:
  if (pair[0].startswith(" ##")) or (pair[0] in ['[CLS]', '[SEP]', '[PAD]']):
    # skip prediction
    continue
  else:
    word_level_predictions.append(pair[1])

# we join tokens, if they are not special ones
str_rep = " ".join([t[0] for t in wp_preds if t[0] not in ['[CLS]', '[SEP]', '[PAD]']]) # .replace(" ##", "") if you want the original sentence (but wont align with labels...
print(str_rep)
print(word_level_predictions)
# Out:
# the client node in a wide area network , which connects to a route ##r node .
# ['O', 'B', 'B', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B', 'O']
